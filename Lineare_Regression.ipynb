# %% [markdown]
# ## Erstell ein lineares Regressionsmodell, um den
#     Preis von Immobilien vorherzusagen.
#     Der Datensatz enthält Informationen über Immobilien, darunter:
#     • Verkaufsdatum
#     • Alter der Immobilie
#     • Entfernung zur nächsten Bahnhaltestelle
#     • Anzahl der Supermärkte in der Umgebung
#     • Immobilienpreis (Zielvariable)
#     Datensatz:
#     https://archive.ics.uci.edu/ml/datasets/Real+estate+valuation+data+set

# %%
# import all inneed packages
import pandas as pd
import openpyxl  #  for reading Excel files

from sklearn.model_selection import train_test_split # for splitting the dataset into training and testing sets

# %%
df = pd.read_excel('./data/Real estate valuation data set.xlsx')
# print(df.head(10))
print(df.columns)
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='str')
